# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280200-max/EPPP-Act-21-clase-celular-en-python-Alejandra-Rivera-0200/blob/main/eppp_act_21_clase_celular_en_python_alejandra_rivera_valenzula_0200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Alejandra Rivera Valenzuela NL = 45 Fecha 22/abril/2026
# ### Clase celular
# ![Infografía Celular](https://raw.githubusercontent.com/a25308051280200-max/ACT-21-clase-celular-en-python-FECHA-abril-2026/refs/heads/main/infografia.png)

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# creacion de objetos (instancia)
cel1 = Celular("Samsung", "Galaxy S23", 800)
cel2 = Celular("Apple", "iPhone 13", 1000)

# llamadas a las funciones para cada objeto celular 1 y celular 2
print("Celular 1:")
cel1.mostrar_info()
cel2.encender()

print("\nCelular 2:")
cel2.mostrar_info()
cel2.encender()

print("programa terminado")
print("Creador de software por Alejandra Rivera Valenzuela NL = 45")
# Out:
# Celular 1:
# Celular: Samsung Galaxy S23, Precio: $800
# El iPhone 13 se ha encendido.
#
# Celular 2:
# Celular: Apple iPhone 13, Precio: $1000
# El iPhone 13 se ha encendido.
# programa terminado
# Creador de software por Alejandra Rivera Valenzuela NL = 45

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/a25308051280200-max/ACT-21-clase-celular-en-python-FECHA-abril-2026/refs/heads/main/Celular.png)
